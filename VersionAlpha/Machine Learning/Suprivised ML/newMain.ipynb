# %%
import pandas as pd
pd.read_csv("../../classData.csv")
# Out:
#                                                                                                                               <<<<<<< HEAD
# G                                                C   B   A   Ia           Ib           Ic           Va          Vb                      Vc
# 1                                                0   0   1   -151.2918124 -9.677451563 85.80016226  0.400749853 -0.132934945  -0.267814907
#                                                              -336.1861826 -76.28326195 18.32889658  0.312731934 -0.123633156  -0.189098779
#                                                              -502.891583  -174.6480233 -80.92466346 0.265728444 -0.114300749  -0.151427695
#                                                              -593.9419049 -217.7033594 -124.8919239 0.235510535 -0.104940254  -0.130570281
# ...                                                                                                                                    ...
# ...

# %%
x
# Out:
# 3
